# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
os.chdir("C:\\Users\\MANDY\\Desktop\\dataset\\bank")

# %%
train=pd.read_csv("bank-additional-full.csv")
# df=pd.read_csv("bank dataset.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
train.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
train.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000866  0.004594 -0.034369  0.024365
# duration       -0.000866  1.000000 -0.071699 -0.047577  0.020640
# campaign        0.004594 -0.071699  1.000000  0.052584 -0.079141
# pdays          -0.034369 -0.047577  0.052584  1.000000 -0.587514
# previous        0.024365  0.020640 -0.079141 -0.587514  1.000000
# emp.var.rate   -0.000371 -0.027968  0.150754  0.271004 -0.420489
# cons.price.idx  0.000857  0.005312  0.127836  0.078889 -0.203130
# cons.conf.idx   0.129372 -0.008173 -0.013733 -0.091342 -0.050936
# euribor3m       0.010767 -0.032897  0.135133  0.296899 -0.454494
# nr.employed    -0.017725 -0.044703  0.144095  0.372605 -0.501333
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000371        0.000857       0.129372   0.010767
# duration           -0.027968        0.005312      -0.008173  -0.032897
# campaign            0.150754        0.127836      -0.013733   0.135133
# pdays               0.271004        0.078889      -0.091342   0.296899
# previous           -0.420489       -0.203130      -0.050936  -0.454494
# emp.var.rate        1.000000        0.775334       0.196041   0.972245
# cons.price.idx      0.775334        1.000000       0.058986   0.688230
# cons.conf.idx       0.196041        0.058986       1.000000   0.277686
# euribor3m           0.972245        0.688230       0.277686   1.000000
# nr.employed         0.906970        0.522034       0.100513   0.945154
#
#                 nr.employed
# age               -0.017725
# duration          -0.044703
# campaign           0.144095
# pdays              0.372605
# previous          -0.501333
# emp.var.rate       0.906970
# cons.price.idx     0.522034
# cons.conf.idx      0.100513
# euribor3m          0.945154
# nr.employed        1.000000

# %%
train.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
train.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
train.hist(column='age',
           by='marital' ,figsize=(6,4),color = "red",
          edgecolor = "green") 
plt.xlabel('age of employee')
plt.ylabel('previous situation of employ')
plt.title('loan is proved or not')
# Out:
# Text(0.5,1,'loan is proved or not')

# %%
train.hist(column='age',
           by='education' ,figsize=(8,6),color = "red",
          edgecolor = "green") 
plt.xlabel('age of employee')
plt.ylabel('education of employ')
plt.title('age vs education')
# Out:
# Text(0.5,1,'loan is proved or not')

# %%
train.hist(column='age',
           by='housing' ,figsize=(6,4),color = "red",
          edgecolor = "green") 
plt.xlabel('age of employee')
plt.ylabel('employ has house or not')
plt.title('in which age theyget house')
# Out:
# Text(0.5,1,'loan is proved or not')

# %%
train.hist(column='age',
           by='emp.var.rate' ,figsize=(8,8),color = "red",
          edgecolor = "green") 
plt.xlabel('age of employee')
plt.ylabel('emply variation rate')
plt.title('age vs emp variation rate')
# Out:
# Text(0.5,1,'loan is proved or not')

# %%
train.hist(column='duration',
           by='day_of_week' ,figsize=(8,8),color = "lightgreen",
          edgecolor = "white") 
plt.xlabel('duraion')
plt.ylabel('day of week')
plt.title('day of week')
# Out:
# Text(0.5,1,'loan is proved or not')

# %%
train.hist(column='age',
           by='loan' ,figsize=(6,4),color = "lightgreen",
          edgecolor = "white") 
plt.xlabel('age of employee')
plt.ylabel('loan')
plt.title('loan is proved or not')
# Out:
# Text(0.5,1,'loan is proved or not')

# %%
train.hist(column='pdays',
           by='day_of_week' ,figsize=(6,4),color = "lightgreen",
          edgecolor = "white") 
plt.xlabel('age of employee')
plt.ylabel('day of week')
plt.title('lprevious day vs day of week')
# Out:
# Text(0.5,1,'lprevious day vs day of week')

# %%
train.hist(column='job',
           by='emp.var.rate' ,figsize=(10,10),color = "red",
          edgecolor = "green") 
plt.xlabel('age of employee')
plt.ylabel('emplyee variation rate')
plt.title('job vs emp.var.rate')
# Out:
# Text(0.5,1,'job vs emp.var.rate')

# %%
train['marital'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
train['day_of_week'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
train['poutcome'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
train['default'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
train['loan'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
train['month'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
train['y'].value_counts().plot(kind='bar', figsize=(4,4),
                                        color="coral", fontsize=13)

plt.show()

# %%
#Scatter plot 
train.plot(kind="scatter",           #The type of plot to be plotted
          x="previous",y="pdays",       #The variables in x and y axis
          color="black",            #Colour of the dots
          figsize=(5,5))            #Figure size


plt.xlabel("previous", fontsize=12)
plt.ylabel("pdays", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
#Scatter plot 
train.plot(kind="scatter",           #The type of plot to be plotted
          x="cons.price.idx",y="emp.var.rate",       #The variables in x and y axis
          color="black",            #Colour of the dots
          figsize=(5,5))            #Figure size


plt.xlabel("cons.rice.idx", fontsize=12)
plt.ylabel("emp.var.idx", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
#Scatter plot 
train.plot(kind="scatter",           #The type of plot to be plotted
          x="emp.var.rate",y="euribor3m",       #The variables in x and y axis
          color="green",            #Colour of the dots
          figsize=(5,5))            #Figure size


plt.xlabel("cons.rice.idx", fontsize=12)
plt.ylabel("emp.var.idx", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
#Scatter plot 
train.plot(kind="scatter",           #The type of plot to be plotted
          x="emp.var.rate",y="nr.employed",       #The variables in x and y axis
          color="green",            #Colour of the dots
          figsize=(5,5))            #Figure size


plt.xlabel("cons.rice.idx", fontsize=12)
plt.ylabel("emp.var.idx", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
sns.pairplot(train,hue='loan',size=1)

# %%
# conclusion:-no perfect corelation

# %%
train.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# #### question:
# * why decision tree
# * how decision tree works
# * buisness empact
# * connect it to real life

# %% [markdown]
# * why decision tree
# * Decision tress often mimic the human level thinking so its so simple to understand the data and make some good interpretations.
# * Decision trees actually make you see the logic for the data to interpret(not like black box algorithms like SVM,NN,etc..)
# * For example : if we are classifying bank loan application for a customer, the decision tree may look like this
# * So what is the decision tree??
# * A decision tree is a tree where each node represents a feature(attribute), each link(branch) represents a decision(rule) and each leaf represents an outcome(categorical or continues value).

# %% [markdown]
# * There are couple of algorithms there to build a decision tree , we only talk about a few which are
# * CART (Classification and Regression Trees) → uses Gini Index(Classification) as metric.
# * ID3 (Iterative Dichotomiser 3) → uses Entropy function and Information gain as metrics.

# %% [markdown]
# * Classification with using the CART algorithm.
# * In CART we use Gini index as a metric,
# * We use the Gini Index as our cost function used to evaluate splits in the dataset.
# * our target variable is Binary variable which means it take two values (Yes and No). There can be 4 combinations.

# %% [markdown]
# * ini Index for Binary Target variable is
# * = 1 — P^2(Target=0) — P^2(Target=1)

# %% [markdown]
# * gini index
#
# * steps:-
# * compute the gini index for data-set
# * for every attribute/feature:
#        * calculate gini index for all categorical values
#        * take average information entropy for the current attribute
#        * calculate the gini gain
# * pick the best gini gain attribute.
# *  Repeat until we get the tree we desired.

# %%
train['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# ### model implitation

# %%
#Importing required libraries
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
train.shape
# Out:
# (41188, 21)

# %%
train.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
train.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le_job = LabelEncoder()
le_marital = LabelEncoder()
le_education=LabelEncoder()
le_default=LabelEncoder()
le_housing=LabelEncoder()
le_loan=LabelEncoder()
le_contact=LabelEncoder()
le_month=LabelEncoder()
le_day_of_week=LabelEncoder()
le_emp.var.rate=LabelEncoder()
le_cons.price.idx=LabelEncoder()
le_cons.conf.idx=LabelEncoder()
le_euribor3m=LabelEncoder()
le_nr.employed=LabelEncoder()
le_y=LabelEncoder()
train['job_encoded'] = le_job.fit_transform(train.job)
train['marital_encoded'] = le_marital.fit_transform(train.marital)
train['education']=le_education.fit_transform(train.eduction)
train['default']=le_default.fit_transform(train.default)
train['housing']=le_housing.fit_transform(train.housing)
train['loan']=le_loan.fit_transform(train.loan)
train['contact']=le_contact.fit_transform(train.contact)
train['month']=le_month.fit_transform(train.month)
train['day_of_week']=le_day_of_week.fit_transform(train.day_of_week)
train['emp.var.rate']=le_emp.var.rate.fit_transform(train.emp.var.rate)
train['cons.price.idx']=le_cons.price.idx_transform(train.cons.price.idx)
train['cons.conf.idx']=le_cons.conf.idx_transform(train.cons.conf.idx)
train['nr.embloyed']=le_nr.embloyed.fit_transform(train.nr.embloyed)
train['euribor3m']=le_euribor3m.fit_transform(train.euribor3m)
train['y']=le_y.fit_transform(train.y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8214e24fe1f1> in <module>()
#       9 le_month=LabelEncoder()
#      10 le_day_of_week=LabelEncoder()
# ---> 11 le_emp.var.rate=LabelEncoder()
#      12 le_cons.price.idx=LabelEncoder()
#      13 le_cons.conf.idx=LabelEncoder()
#
# NameError: name 'le_emp' is not defined

# %%
#seperating independent and dependent variables
y = train['deposit']
X = data.drop(['deposit'], axis=1)
